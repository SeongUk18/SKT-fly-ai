# %%
# 코랩에서 한글 사용
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,098 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# Selecting previously unselected package fonts-nanum-coding.
# (Reading database ... 121948 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# 한글 폰트 가져오기
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)

# %%
import pandas as pd

car_data = pd.read_csv('/content/car.csv', encoding='cp949')

car_data.head()
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
#
#         리콜개시일                                               리콜사유
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# 1  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 2  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 3  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 4  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1419 entries, 0 to 1418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1419 non-null   object
#  1   차명        1419 non-null   object
#  2   생산기간(부터)  1419 non-null   object
#  3   생산기간(까지)  1419 non-null   object
#  4   리콜개시일     1419 non-null   object
#  5   리콜사유      1419 non-null   object
# dtypes: object(6)
# memory usage: 66.6+ KB

# %%
new_data = car_data.groupby('제작자')
len(new_data.count())
# Out:
# 36

# %%
new_data.count()
# Out:
#                    차명  생산기간(부터)  생산기간(까지)  리콜개시일  리콜사유
# 제작자
# (유)기흥모터스           21        21        21     21    21
# (주) 바이크코리아          3         3         3      3     3
# (주) 한국모터트레이딩        3         3         3      3     3
# (주)다산중공업            2         2         2      2     2
# (주)볼보자동차코리아        13        13        13     13    13
# (주)스포츠모터사이클코리아      1         1         1      1     1
# (주)에프엠케이           31        31        31     31    31
# (주)재규어랜드로버코리아      26        26        26     26    26
# (주)피라인              5         5         5      5     5
# 기아주식회사             38        38        38     38    38
# 기흥인터내셔널 유한회사        1         1         1      1     1
# 다임러트럭코리아(주)         9         9         9      9     9
# 대전기계공업(주)           4         4         4      4     4
# 르노코리아자동차 주식회사       7         7         7      7     7
# 만트럭버스코리아(주)        41        41        41     41    41
# 메르세데스벤츠코리아(주)     330       330       330    330   330
# 모토스타코리아(주)          2         2         2      2     2
# 범한자동차 주식회사          4         4         4      4     4
# 볼보트럭코리아(주)          4         4         4      4     4
# 비엠더블유코리아(주)       432       432       432    432   432
# 스카니아코리아그룹(주)       10        10        10     10    10
# 스텔란티스코리아주식회사       31        31        31     31    31
# 유한회사 모토로싸           1         1         1      1     1
# 주식회사 마이브            1         1         1      1     1
# 지엠코리아(주)            4         4         4      4     4
# 테슬라코리아 유한회사        20        20        20     20    20
# 포드세일즈서비스코리아(유)     37        37        37     37    37
# 포르쉐코리아 주식회사        20        20        20     20    20
# 폭스바겐그룹코리아 주식회사    216       216       216    216   216
# 폴스타오토모티브코리아 유한회사    1         1         1      1     1
# 한국지엠(주)             3         3         3      3     3
# 한국토요타자동차(주)         5         5         5      5     5
# 한신특장                1         1         1      1     1
# 현대자동차(주)           61        61        61     61    61
# 혼다코리아(주)           15        15        15     15    15
# 화창상사(주)            16        16        16     16    16

# %%
new_data = car_data.groupby('차명')
len(new_data)
# Out:
# 728

# %%
new_data.count()
# Out:
#                    제작자  생산기간(부터)  생산기간(까지)  리콜개시일  리콜사유
# 차명
# 1 Series Sport       1         1         1      1     1
# 118d                 2         2         2      2     2
# 120d                 2         2         2      2     2
# 128i                 5         5         5      5     5
# 1290 SUPER DUKE R    1         1         1      1     1
# ...                ...       ...       ...    ...   ...
# 페라리Roma              1         1         1      1     1
# 페라리캘리포니아             1         1         1      1     1
# 페라리캘리포니아T            1         1         1      1     1
# 플라잉스퍼                1         1         1      1     1
# 한신특장 울트라 고소작업차       1         1         1      1     1
#
# [728 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_15['제작자'].plot(kind='hist', bins=20, title='제작자')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_16['생산기간(부터)'].plot(kind='hist', bins=20, title='생산기간(부터)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44620 (\N{HANGUL SYLLABLE GGA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_17['생산기간(까지)'].plot(kind='hist', bins=20, title='생산기간(까지)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_18['리콜개시일'].plot(kind='hist', bins=20, title='리콜개시일')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='제작자', y='생산기간(부터)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44620 (\N{HANGUL SYLLABLE GGA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='생산기간(부터)', y='생산기간(까지)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44620 (\N{HANGUL SYLLABLE GGA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='생산기간(까지)', y='리콜개시일', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='리콜개시일', y='리콜사유', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 54168 (\N{HANGUL SYLLABLE PE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_23['제작자'].plot(kind='line', figsize=(8, 4), title='제작자')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 54168 (\N{HANGUL SYLLABLE PE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_24['생산기간(부터)'].plot(kind='line', figsize=(8, 4), title='생산기간(부터)')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44620 (\N{HANGUL SYLLABLE GGA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 54168 (\N{HANGUL SYLLABLE PE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_25['생산기간(까지)'].plot(kind='line', figsize=(8, 4), title='생산기간(까지)')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 54168 (\N{HANGUL SYLLABLE PE}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_26['리콜개시일'].plot(kind='line', figsize=(8, 4), title='리콜개시일')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_26['리콜개시일'].plot(kind='line', figsize=(8, 4), title='리콜개시일')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
car_data = car_data.loc[pd.to_datetime(car_data['리콜개시일']).dt.year == 2022]

car_data.head()
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
#
#         리콜개시일                                               리콜사유
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# 1  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 2  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 3  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 4  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1419 entries, 0 to 1418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1419 non-null   object
#  1   차명        1419 non-null   object
#  2   생산기간(부터)  1419 non-null   object
#  3   생산기간(까지)  1419 non-null   object
#  4   리콜개시일     1419 non-null   object
#  5   리콜사유      1419 non-null   object
# dtypes: object(6)
# memory usage: 109.9+ KB

# %%
grouped_car_df = car_data.groupby('차명').agg({
    '리콜개시일': 'count',
    '리콜사유': lambda x: list(x)
}).reset_index()

grouped_car_df.head()
# Out:
#                   차명  리콜개시일                                               리콜사유
# 0     1 Series Sport      1                       [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성]
# 1               118d      2  [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...
# 2               120d      2  [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...
# 3               128i      5  [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...
# 4  1290 SUPER DUKE R      1  [메인 와이어링 하네스와 차체 구성 부품 간의 간섭으로 인한 피복 손상으로 배선 단...

# %%
sorted_car_df = grouped_car_df.sort_values(by='리콜개시일', ascending=False)

sorted_car_df.head()
# Out:
#         차명  리콜개시일                                               리콜사유
# 51    328i     25  [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...
# 525    TGX     22  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...
# 524    TGS     18  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...
# 230  C 300     13  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 54   328xi     11  [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...

# %%
top_20_car_df = sorted_car_df.head(20)
top_20_car_df
# Out:
#                                    차명  리콜개시일  \
# 51                               328i     25
# 525                               TGX     22
# 524                               TGS     18
# 230                             C 300     13
# 54                              328xi     11
# 486                           S 350 d     10
# 497                      S 580 4MATIC     10
# 406              Maybach S 580 4MATIC      9
# 489                    S 400 d 4MATIC      9
# 492                      S 500 4MATIC      9
# 224                      C 200 4MATIC      9
# 324                  GLE 300 d 4MATIC      9
# 424                           Model 3      9
# 64                               520d      8
# 629                            스카니아카고      8
# 276                      E 450 4MATIC      7
# 66                        520d xDrive      7
# 194  BMW X3 xDrive20d M Sport Package      6
# 314                  GLC 220 d 4MATIC      6
# 319                    GLC 300 4MATIC      6
#
#                                                   리콜사유
# 51   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...
# 525  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...
# 524  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...
# 230  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 54   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...
# 486  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...
# 497  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 406  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 489  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...
# 492  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...
# 224  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 324  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...
# 424  [미디어 컨트롤 유닛 소프트웨어 오류로 특정 상황에서 운전자가 안전벨트를 채우지 않...
# 64   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...
# 629  [타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다., 타...
# 276  [생산 공정 상 오류로 인하여 전방 좌측 충돌 센서의 커넥터가 제대로 체결되지 않았...
# 66   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...
# 194  [엔진 컨트롤 유닛 (DDE)의 진단 관련 소프트웨어의 오류가 있는 것을 확인하였습...
# 314  [크랭크샤프트의 내구성 부족으로 인해 엔진 부하가 높을 경우 크랭크샤프트가 파손될 ...
# 319  [공급 업체 생산 공정 상 오류로 인하여 어린이 보호 잠금장치가 없는 도어 록(do...

# %%
from matplotlib import pyplot as plt
top_20_car_df['리콜개시일'].plot(kind='hist', bins=20, title='리콜개시일')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
grouped_car_data = car_data.groupby('차명').agg({
    '생산기간(부터)': 'first',
    '리콜사유': lambda x: list(x),
    '제작자': 'first'
}).reset_index()

# Count occurrences and sort by count in descending order
grouped_car_data['count'] = car_data.groupby('차명').size().values
sorted_grouped_car_data = grouped_car_data.sort_values(by='count', ascending=False)

# Extract top 20
top_20_cars = sorted_grouped_car_data.head(20)

# %%
top_20_cars
# Out:
#                                    차명    생산기간(부터)  \
# 51                               328i  2009-11-03
# 525                               TGX  2019-07-24
# 524                               TGS  2019-12-13
# 230                             C 300  2021-03-15
# 54                              328xi  2009-09-14
# 486                           S 350 d  2020-11-24
# 497                      S 580 4MATIC  2020-07-09
# 406              Maybach S 580 4MATIC  2020-09-11
# 489                    S 400 d 4MATIC  2021-07-09
# 492                      S 500 4MATIC  2021-07-28
# 224                      C 200 4MATIC  2021-03-16
# 324                  GLE 300 d 4MATIC  2021-01-27
# 424                           Model 3  2019-07-31
# 64                               520d  2016-09-13
# 629                            스카니아카고  2021-04-01
# 276                      E 450 4MATIC  2020-09-28
# 66                        520d xDrive  2016-05-23
# 194  BMW X3 xDrive20d M Sport Package  2019-04-05
# 314                  GLC 220 d 4MATIC  2020-08-06
# 319                    GLC 300 4MATIC  2021-02-23
#
#                                                   리콜사유            제작자  count
# 51   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...    비엠더블유코리아(주)     25
# 525  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...    만트럭버스코리아(주)     22
# 524  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...    만트럭버스코리아(주)     18
# 230  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)     13
# 54   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...    비엠더블유코리아(주)     11
# 486  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)     10
# 497  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)     10
# 406  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 489  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)      9
# 492  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)      9
# 224  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 324  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 424  [미디어 컨트롤 유닛 소프트웨어 오류로 특정 상황에서 운전자가 안전벨트를 채우지 않...    테슬라코리아 유한회사      9
# 64   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...    비엠더블유코리아(주)      8
# 629  [타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다., 타...   스카니아코리아그룹(주)      8
# 276  [생산 공정 상 오류로 인하여 전방 좌측 충돌 센서의 커넥터가 제대로 체결되지 않았...  메르세데스벤츠코리아(주)      7
# 66   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...    비엠더블유코리아(주)      7
# 194  [엔진 컨트롤 유닛 (DDE)의 진단 관련 소프트웨어의 오류가 있는 것을 확인하였습...    비엠더블유코리아(주)      6
# 314  [크랭크샤프트의 내구성 부족으로 인해 엔진 부하가 높을 경우 크랭크샤프트가 파손될 ...  메르세데스벤츠코리아(주)      6
# 319  [공급 업체 생산 공정 상 오류로 인하여 어린이 보호 잠금장치가 없는 도어 록(do...  메르세데스벤츠코리아(주)      6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a bar plot
sns.barplot(x='count', y='차명', data=top_20_cars, palette='viridis')

# Add titles and labels
plt.title('Top 20 Cars by Count')
plt.xlabel('Count')
plt.ylabel('Car Model')

# Show the plot
plt.show()

# %%
grouped_car_data2 = grouped_car_data.groupby('제작자').agg({
    '리콜사유': lambda x: [reason for sublist in x for reason in sublist]  # Flatten the list of lists
}).reset_index()

# Count occurrences and sort by count in descending order
grouped_car_data2['count'] = grouped_car_data.groupby('제작자').size().values
sorted_grouped_car_data2 = grouped_car_data2.sort_values(by='count', ascending=False)

# %%
sorted_grouped_car_data2
# Out:
#                  제작자                                               리콜사유  count
# 19       비엠더블유코리아(주)  [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...    182
# 15     메르세데스벤츠코리아(주)  [후방 카메라의 소프트웨어 오류로 인하여 차량의 후진 기어 작동 시 후방 영상이 중...    142
# 28    폭스바겐그룹코리아 주식회사  [특정 기간 동안 생산된 일부 차량의 동승자석 승객 감지 시스템의 커넥터와 배선에서...    105
# 33          현대자동차(주)  [전자식변속제어장치(SCU) 로직 미흡으로 인해 경사로 주차 중 변속장치의 주차유지...     47
# 26    포드세일즈서비스코리아(유)  [2011-2013년식 Explorer 차량 중 양쪽 후륜 바퀴 너클 중 하나 또는...     30
# 6           (주)에프엠케이  [브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레...     30
# 9             기아주식회사  [전자식변속제어장치(SCU) 로직 미흡으로 인해 경사로 주차 중 변속장치의 주차유지...     28
# 21      스텔란티스코리아주식회사  [엔진 오일이 부족할 경우 엔진 오일 경고등이 점등되어 엔진 오일이 부족한 사실을 ...     25
# 0           (유)기흥모터스  [브레이크 레버에서 손/발을 떼고 있을 때 브레이크등이 켜질 수 있음., 브레이크 ...     21
# 7      (주)재규어랜드로버코리아  [당사에서 수입한‘더 뉴 레인지로버’일부 차량의 제조 과정에서 배기가스 후처리장치(...     21
# 34          혼다코리아(주)  [파워윈도우 마스터스위치 사양 오류로 인해 윈도우 조작 시 안전에 영향을 끼칠 가능...     12
# 35           화창상사(주)  [차량제어모듈(VEHICLE CONTROL MODULE) 및 커넥터 접촉 불량(헐거...     11
# 4        (주)볼보자동차코리아  [국내 수입된 차량에서 계기판 소프트웨어의 속도계 설정값 오류로 인해 계기판에 표시...     10
# 27       포르쉐코리아 주식회사  [계기판 소프트웨어의 오류로 브레이크 진공펌프의 고장 시 자동차 및 자동차부품의 성...      8
# 31       한국토요타자동차(주)  [차선 유지 보조장치(LTA*)의 소프트웨어 오류로, 장치 작동 시 핸들의 중립위치...      5
# 13     르노코리아자동차 주식회사  [XM3 TCe260과 CAPTUR TCe260 차량에 장착된 연료 펌프 내부 구성...      4
# 17        범한자동차 주식회사  [차량 전·후면 상부 및 전면 하부 DECO LAMP는 자동차 안전기준 제47조(그...      4
# 25       테슬라코리아 유한회사  [미디어 컨트롤 유닛 소프트웨어 오류로 특정 상황에서 운전자가 안전벨트를 채우지 않...      4
# 12         대전기계공업(주)  [경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 ...      3
# 2       (주) 한국모터트레이딩  [계기판소프트웨어 오류로 인해 계기판 C PU 에서 계 기 판 화 면 으로 데이터 ...      3
# 30           한국지엠(주)  [바디 컨트롤 모듈 소프트웨어 오류로 인해 전조등 점등 시 주간주행등이 꺼지지 않고...      3
# 24          지엠코리아(주)  [작업자의 실수로 연료 탱크 내의 롤오버 밸브가 정위치에 조립되지 않아 시간이 지남...      3
# 8             (주)피라인  [제원통보한 총중량 및 중량분포가 실차 제원과 일치하지 않아 자동차 및 자동차 부품...      3
# 1         (주) 바이크코리아  [뒷 브레이크 디스크 고정볼트의 나사 풀림 방지제의 내구성 부족으로 지속 운행 시 ...      3
# 11       다임러트럭코리아(주)  [스프린터 907 차량 생산 이후 테스트 및 분석과정에서 전자식주행안정(ESP) 컨...      3
# 14       만트럭버스코리아(주)  [크랭크축의 가공상의 문제로 파손(절손) 가능성이 있습니다., 메인 퓨즈 박스의 공...      3
# 18        볼보트럭코리아(주)  [2021.3.12 ~ 2022.3.17 생산된 볼보 FH/FM 트랙터/카고 차종의...      3
# 20      스카니아코리아그룹(주)  [타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다., 타...      2
# 16        모토스타코리아(주)             [등화장치(차폭등) 색도기준 미달, 등화장치(차폭등) 색도기준 미달]      2
# 3           (주)다산중공업  [㈜다산중공업에서는 CT290S 등 6개 모델의 후미 마운팅볼트가 반복 피로하중에 ...      2
# 22         유한회사 모토로싸  [엔진 오일 쿨러 유입 호스와 리턴 호스가 접촉되게 설계되어 차량 진동 등에 의해 ...      1
# 23          주식회사 마이브  [자동차의 에너지소비효율, 온실가스 배출량 및 연료소비율 시험방법 등에 관한 고시의...      1
# 5     (주)스포츠모터사이클코리아  [메인 와이어링 하네스와 차체 구성 부품 간의 간섭으로 인한 피복 손상으로 배선 단...      1
# 10      기흥인터내셔널 유한회사  [맥라렌 GT모델에서 에어백 제어 장치(Occupant restraint contr...      1
# 29  폴스타오토모티브코리아 유한회사  [국내 수입된 차량에서 계기판 소프트웨어의 속도계 설정값 오류로 인해 계기판에 표시...      1
# 32              한신특장                                         [인증 중량 초과]      1

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a bar plot
sns.barplot(x='count', y='제작자', data=sorted_grouped_car_data2, palette='viridis')

# Add titles and labels
plt.title('Count')
plt.xlabel('Count')
plt.ylabel('Car Model')

# Show the plot
plt.show()

# %%
# Prepare the data for plotting
top_20_cars['제작자'] = top_20_cars['제작자'].astype(str)  # Ensure the '제작자' column is of type string

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a bar plot with colors based on '제작자'
unique_manufacturers = top_20_cars['제작자'].unique()
palette = sns.color_palette('viridis', len(unique_manufacturers))
color_mapping = {manufacturer: palette[i] for i, manufacturer in enumerate(unique_manufacturers)}

# Apply the color mapping to the plot
sns.barplot(
    x='count',
    y='차명',
    data=top_20_cars,
    palette=[color_mapping[manufacturer] for manufacturer in top_20_cars['제작자']]
)

# Add titles and labels
plt.title('Top 20 Cars by Count')
plt.xlabel('Count')
plt.ylabel('Car Model')

# Create a legend
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_mapping[manufacturer], markersize=10) for manufacturer in unique_manufacturers]
plt.legend(handles, unique_manufacturers, title='제작자')

# Show the plot
plt.show()

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 39.5 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from collections import Counter

# Define a list of Korean stopwords
stopwords = set([
    '으로', '에', '을', '의', '가', '이', '은', '는', '로', '에서', '와', '과', '도', '다', '를', '한', '를', '합니다', '등', '것', '및', '그', '또한', '그리고', '하지만', '더', '하지', '것이', '있다', '수', '때', '있습니다'
])

# Initialize the Okt (Open Korean Text) tokenizer
okt = Okt()

# Function to preprocess text by removing stopwords
def preprocess_text(text):
    tokens = okt.nouns(text)
    filtered_tokens = [word for word in tokens if word not in stopwords]
    return ' '.join(filtered_tokens)

# Combine all recall reasons for each manufacturer into a single string and preprocess
manufacturer_reasons = top_20_cars.groupby('제작자')['리콜사유'].apply(lambda x: ' '.join([' '.join(reason) for reason in x]))
manufacturer_reasons = manufacturer_reasons.apply(preprocess_text)

# Generate and plot a word cloud for each manufacturer
plt.figure(figsize=(20, 15))
for i, (manufacturer, reasons) in enumerate(manufacturer_reasons.items()):
    plt.subplot(4, 5, i+1)
    wordcloud = WordCloud(width=800, height=400, background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf').generate(reasons)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(manufacturer, fontsize=14)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# 코랩에서 한글 사용
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
# 한글 폰트 가져오기
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)

# %%
import pandas as pd

car_data = pd.read_csv('/content/car.csv', encoding='cp949')

car_data.head()
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
#
#         리콜개시일                                               리콜사유
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# 1  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 2  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 3  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 4  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...

# %%
car_data = car_data.loc[pd.to_datetime(car_data['리콜개시일']).dt.year == 2022]

car_data.head()
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
#
#         리콜개시일                                               리콜사유
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# 1  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 2  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 3  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# 4  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...

# %%
grouped_car_data = car_data.groupby('차명').agg({
    '생산기간(부터)': 'first',
    '리콜사유': lambda x: list(x),
    '제작자': 'first'
}).reset_index()

# Count occurrences and sort by count in descending order
grouped_car_data['count'] = car_data.groupby('차명').size().values
sorted_grouped_car_data = grouped_car_data.sort_values(by='count', ascending=False)

# Extract top 20
top_20_cars = sorted_grouped_car_data.head(20)

# %%
top_20_cars
# Out:
#                                    차명    생산기간(부터)  \
# 51                               328i  2009-11-03
# 525                               TGX  2019-07-24
# 524                               TGS  2019-12-13
# 230                             C 300  2021-03-15
# 54                              328xi  2009-09-14
# 486                           S 350 d  2020-11-24
# 497                      S 580 4MATIC  2020-07-09
# 406              Maybach S 580 4MATIC  2020-09-11
# 489                    S 400 d 4MATIC  2021-07-09
# 492                      S 500 4MATIC  2021-07-28
# 224                      C 200 4MATIC  2021-03-16
# 324                  GLE 300 d 4MATIC  2021-01-27
# 424                           Model 3  2019-07-31
# 64                               520d  2016-09-13
# 629                            스카니아카고  2021-04-01
# 276                      E 450 4MATIC  2020-09-28
# 66                        520d xDrive  2016-05-23
# 194  BMW X3 xDrive20d M Sport Package  2019-04-05
# 314                  GLC 220 d 4MATIC  2020-08-06
# 319                    GLC 300 4MATIC  2021-02-23
#
#                                                   리콜사유            제작자  count
# 51   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...    비엠더블유코리아(주)     25
# 525  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...    만트럭버스코리아(주)     22
# 524  [메인 퓨즈 박스의 공급업체의 신규 조립공장에서 생산 초기에 공정의 문제(퓨즈 고정...    만트럭버스코리아(주)     18
# 230  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)     13
# 54   [블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive tempera...    비엠더블유코리아(주)     11
# 486  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)     10
# 497  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)     10
# 406  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 489  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)      9
# 492  [메르세데스 미 서비스(Mercedes me)를 위해 차량과 본사 서버(backen...  메르세데스벤츠코리아(주)      9
# 224  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 324  [엔진 컨트롤 유닛의 소프트웨어 오류로 인해 엔진 시동 후 차량 도난방지 장치(ve...  메르세데스벤츠코리아(주)      9
# 424  [미디어 컨트롤 유닛 소프트웨어 오류로 특정 상황에서 운전자가 안전벨트를 채우지 않...    테슬라코리아 유한회사      9
# 64   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...    비엠더블유코리아(주)      8
# 629  [타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다., 타...   스카니아코리아그룹(주)      8
# 276  [생산 공정 상 오류로 인하여 전방 좌측 충돌 센서의 커넥터가 제대로 체결되지 않았...  메르세데스벤츠코리아(주)      7
# 66   [배기가스재순환장치 쿨러 내부 냉각수 누설 가능성, 배기가스재순환장치 쿨러 내부 냉...    비엠더블유코리아(주)      7
# 194  [엔진 컨트롤 유닛 (DDE)의 진단 관련 소프트웨어의 오류가 있는 것을 확인하였습...    비엠더블유코리아(주)      6
# 314  [크랭크샤프트의 내구성 부족으로 인해 엔진 부하가 높을 경우 크랭크샤프트가 파손될 ...  메르세데스벤츠코리아(주)      6
# 319  [공급 업체 생산 공정 상 오류로 인하여 어린이 보호 잠금장치가 없는 도어 록(do...  메르세데스벤츠코리아(주)      6

# %%
# Prepare the data for plotting
top_20_cars['제작자'] = top_20_cars['제작자'].astype(str)  # Ensure the '제작자' column is of type string

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a bar plot with colors based on '제작자'
unique_manufacturers = top_20_cars['제작자'].unique()
palette = sns.color_palette('viridis', len(unique_manufacturers))
color_mapping = {manufacturer: palette[i] for i, manufacturer in enumerate(unique_manufacturers)}

# Apply the color mapping to the plot
sns.barplot(
    x='count',
    y='차명',
    data=top_20_cars,
    palette=[color_mapping[manufacturer] for manufacturer in top_20_cars['제작자']]
)

# Add titles and labels
plt.title('Top 20 Cars by Count')
plt.xlabel('Count')
plt.ylabel('Car Model')

# Create a legend
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_mapping[manufacturer], markersize=10) for manufacturer in unique_manufacturers]
plt.legend(handles, unique_manufacturers, title='제작자')

# Show the plot
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from collections import Counter

# Define a list of Korean stopwords
stopwords = set([
    '으로', '에', '을', '의', '가', '이', '은', '는', '로', '에서', '와', '과', '도', '다', '를', '한', '를', '합니다', '등', '것', '및', '그', '또한', '그리고', '하지만', '더', '하지', '것이', '있다', '수', '때', '있습니다'
])

# Initialize the Okt (Open Korean Text) tokenizer
okt = Okt()

# Function to preprocess text by removing stopwords
def preprocess_text(text):
    tokens = okt.nouns(text)
    filtered_tokens = [word for word in tokens if word not in stopwords]
    return ' '.join(filtered_tokens)

# Combine all recall reasons for each manufacturer into a single string and preprocess
manufacturer_reasons = top_20_cars.groupby('제작자')['리콜사유'].apply(lambda x: ' '.join([' '.join(reason) for reason in x]))
manufacturer_reasons = manufacturer_reasons.apply(preprocess_text)

# Generate and plot a word cloud for each manufacturer
plt.figure(figsize=(20, 15))
for i, (manufacturer, reasons) in enumerate(manufacturer_reasons.items()):
    plt.subplot(4, 5, i+1)
    wordcloud = WordCloud(width=800, height=400, background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf').generate(reasons)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(manufacturer, fontsize=14)
    plt.axis('off')

plt.tight_layout()
plt.show()
