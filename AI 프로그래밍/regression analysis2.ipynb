# %%
import pandas as pd

# 데이터셋 분리 함수
from sklearn.model_selection import train_test_split
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('car5_train.csv')
data
# Out:
#      Unnamed: 0  typeofoil  displacement  empty_vehicle_weight  \
# 0             5          0          1580                  1425
# 1            36          1          2151                  1800
# 2           237          1          2497                  1910
# 3           204          0          2497                  2035
# 4           142          1          2199                  1780
# ..          ...        ...           ...                   ...
# 196         216          0          2497                  2155
# 197          37          1          2151                  1755
# 198         159          0          2497                  1880
# 199         114          0          1341                  1345
# 200          72          1          1598                  1490
#
#      downtown_fuel_efficiency  highway_fuel_efficiency  fuel_efficiency  \
# 0                        18.1                     16.6             17.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                201 non-null    int64
#  1   typeofoil                 201 non-null    int64
#  2   displacement              201 non-null    int64
#  3   empty_vehicle_weight      201 non-null    int64
#  4   downtown_fuel_efficiency  201 non-null    float64
#  5   highway_fuel_efficiency   201 non-null    float64
#  6   fuel_efficiency           201 non-null    float64
#  7   typeofcar                 201 non-null    int64
#  8   CO2                       201 non-null    int64
#  9   grade                     201 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 15.8 KB

# %%
## figsize()는 plot()의 기본 크기를 지정합니다.
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()  # Axes 생성
# origin, acceleration, horsepower, weight
### gca()
### gca()로 현재의 Axes를, gcf()로 현재의 Figure 객체를 구할 수 있다.

data.hist(ax=ax)
plt.show()
# Out:
# <ipython-input-33-f85824ed9167>:8: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax=ax)

# %%
# 상관계수 매트릭스 계산
correlation_matrix = data.corr()

# 상관계수 매트릭스 출력
print(correlation_matrix)

# 상관계수 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Auto MPG Dataset')
plt.show()
# Out:
#                           Unnamed: 0  typeofoil  displacement  \
# Unnamed: 0                  1.000000   0.044673      0.624214
# typeofoil                   0.044673   1.000000      0.008319
# displacement                0.624214   0.008319      1.000000
# empty_vehicle_weight        0.584908   0.101635      0.799469
# downtown_fuel_efficiency   -0.908311  -0.098886     -0.590343
# highway_fuel_efficiency    -0.939495  -0.062636     -0.631986
# fuel_efficiency            -0.934513  -0.085922     -0.616185
# typeofcar                   0.467510   0.324425      0.089059
# CO2                         0.891843   0.061055      0.722219
# grade                       0.975901   0.019274      0.640278
#
#                           empty_vehicle_weight  downtown_fuel_efficiency  \
# Unnamed: 0                            0.584908                 -0.908311
# typeofoil                             0.101635                 -0.098886
# ...

# %%
data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2', 'typeofcar', 'grade']]

data
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2  typeofcar  grade
# 0            0          1580                  1425   92          0      1
# 1            1          2151                  1800  134          1      2
# 2            1          2497                  1910  212          1      5
# 3            0          2497                  2035  188          1      5
# 4            1          2199                  1780  141          1      3
# ..         ...           ...                   ...  ...        ...    ...
# 196          0          2497                  2155  194          1      5
# 197          1          2151                  1755  133          1      2
# 198          0          2497                  1880  174          1      4
# 199          0          1341                  1345  127          1      3
# 200          1          1598                  1490  129          1      2
#
# [201 rows x 6 columns]

# %%
data = data.loc[data['typeofcar'] == 1]

data
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2  typeofcar  grade
# 1            1          2151                  1800  134          1      2
# 2            1          2497                  1910  212          1      5
# 3            0          2497                  2035  188          1      5
# 4            1          2199                  1780  141          1      3
# 6            1          1582                  1390  108          1      1
# ..         ...           ...                   ...  ...        ...    ...
# 196          0          2497                  2155  194          1      5
# 197          1          2151                  1755  133          1      2
# 198          0          2497                  1880  174          1      4
# 199          0          1341                  1345  127          1      3
# 200          1          1598                  1490  129          1      2
#
# [181 rows x 6 columns]

# %%
data = data.loc[data['typeofoil'] == 1]

data
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2  typeofcar  grade
# 1            1          2151                  1800  134          1      2
# 2            1          2497                  1910  212          1      5
# 4            1          2199                  1780  141          1      3
# 6            1          1582                  1390  108          1      1
# 7            1          2151                  1785  133          1      2
# ..         ...           ...                   ...  ...        ...    ...
# 192          1          1598                  1425  113          1      1
# 194          1          1598                  1580  115          1      1
# 195          1          2157                  2150  177          1      4
# 197          1          2151                  1755  133          1      2
# 200          1          1598                  1490  129          1      2
#
# [94 rows x 6 columns]

# %%
print(data.isnull().sum())
# Out:
# typeofoil               0
# displacement            0
# empty_vehicle_weight    0
# CO2                     0
# typeofcar               0
# grade                   0
# dtype: int64

# %%
df_x_data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2']]

df_x_data
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2
# 1            1          2151                  1800  134
# 2            1          2497                  1910  212
# 4            1          2199                  1780  141
# 6            1          1582                  1390  108
# 7            1          2151                  1785  133
# ..         ...           ...                   ...  ...
# 192          1          1598                  1425  113
# 194          1          1598                  1580  115
# 195          1          2157                  2150  177
# 197          1          2151                  1755  133
# 200          1          1598                  1490  129
#
# [94 rows x 4 columns]

# %%
df_y_data = data['grade']

df_y_data
# Out:
# 1      2
# 2      5
# 4      3
# 6      1
# 7      2
#       ..
# 192    1
# 194    1
# 195    4
# 197    2
# 200    2
# Name: grade, Length: 94, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.2, random_state=42)

X_train
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2
# 149          1          1597                  1475  130
# 28           1          1597                  1525  130
# 154          1          1597                  1535  134
# 174          1          2497                  1845  216
# 66           1          1598                  1470  123
# ..         ...           ...                   ...  ...
# 133          1          2151                  1820  144
# 158          1          1597                  1525  123
# 26           1          2497                  2440  220
# 197          1          2151                  1755  133
# 120          1          1598                  1385  105
#
# [75 rows x 4 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 149 to 120
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   typeofoil             75 non-null     int64
#  1   displacement          75 non-null     int64
#  2   empty_vehicle_weight  75 non-null     int64
#  3   CO2                   75 non-null     int64
# dtypes: int64(4)
# memory usage: 2.9 KB

# %%
print(X_train.isnull().sum())
# Out:
# typeofoil               0
# displacement            0
# empty_vehicle_weight    0
# CO2                     0
# dtype: int64

# %%
# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 0.07347997800273773
# R^2 Score: 0.9473685078194676
# Intercept: -2.478156803981242
# Coefficient: [0.00000000e+00 2.30410521e-04 1.45358987e-06 3.18358576e-02]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 실제 값과 예측 값의 비교 산점도
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6, color='b')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual MPG')
plt.ylabel('Predicted MPG')
plt.title('Actual vs. Predicted MPG')
plt.show()

# %%
data = pd.read_csv('car5_train.csv')
data
# Out:
#      Unnamed: 0  typeofoil  displacement  empty_vehicle_weight  \
# 0             5          0          1580                  1425
# 1            36          1          2151                  1800
# 2           237          1          2497                  1910
# 3           204          0          2497                  2035
# 4           142          1          2199                  1780
# ..          ...        ...           ...                   ...
# 196         216          0          2497                  2155
# 197          37          1          2151                  1755
# 198         159          0          2497                  1880
# 199         114          0          1341                  1345
# 200          72          1          1598                  1490
#
#      downtown_fuel_efficiency  highway_fuel_efficiency  fuel_efficiency  \
# 0                        18.1                     16.6             17.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                201 non-null    int64
#  1   typeofoil                 201 non-null    int64
#  2   displacement              201 non-null    int64
#  3   empty_vehicle_weight      201 non-null    int64
#  4   downtown_fuel_efficiency  201 non-null    float64
#  5   highway_fuel_efficiency   201 non-null    float64
#  6   fuel_efficiency           201 non-null    float64
#  7   typeofcar                 201 non-null    int64
#  8   CO2                       201 non-null    int64
#  9   grade                     201 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 15.8 KB

# %%
data = data.loc[data['typeofcar'] == 1]
data = data.loc[data['typeofoil'] != 2]
data
# Out:
#      Unnamed: 0  typeofoil  displacement  empty_vehicle_weight  \
# 1            36          1          2151                  1800
# 2           237          1          2497                  1910
# 3           204          0          2497                  2035
# 4           142          1          2199                  1780
# 6            18          1          1582                  1390
# ..          ...        ...           ...                   ...
# 196         216          0          2497                  2155
# 197          37          1          2151                  1755
# 198         159          0          2497                  1880
# 199         114          0          1341                  1345
# 200          72          1          1598                  1490
#
#      downtown_fuel_efficiency  highway_fuel_efficiency  fuel_efficiency  \
# 1                        12.8                     16.3             14.2
# ...

# %%
df_x_data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2']]

df_x_data
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2
# 1            1          2151                  1800  134
# 2            1          2497                  1910  212
# 3            0          2497                  2035  188
# 4            1          2199                  1780  141
# 6            1          1582                  1390  108
# ..         ...           ...                   ...  ...
# 196          0          2497                  2155  194
# 197          1          2151                  1755  133
# 198          0          2497                  1880  174
# 199          0          1341                  1345  127
# 200          1          1598                  1490  129
#
# [169 rows x 4 columns]

# %%
df_y_data = data['grade']

df_y_data
# Out:
# 1      2
# 2      5
# 3      5
# 4      3
# 6      1
#       ..
# 196    5
# 197    2
# 198    4
# 199    3
# 200    2
# Name: grade, Length: 169, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.2, random_state=42)

X_train
# Out:
#      typeofoil  displacement  empty_vehicle_weight  CO2
# 85           0          1199                  1340  130
# 164          0          1341                  1400  118
# 3            0          2497                  2035  188
# 115          0          2497                  2100  188
# 162          1          2996                  2285  179
# ..         ...           ...                   ...  ...
# 87           1          2157                  2060  188
# 129          1          2996                  2310  188
# 17           1          1995                  1700  131
# 114          1          2157                  2050  171
# 124          0          1497                  1360  140
#
# [135 rows x 4 columns]

# %% [markdown]
# **경우 차량 분석 결과**

# %%
# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 0.0947963532908551
# R^2 Score: 0.9292546259494974
# Intercept: -1.3678820329913441
# Coefficient: [-7.74410065e-01 -3.72358491e-05  1.27445788e-04  3.16024252e-02]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 실제 값과 예측 값의 비교 산점도
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6, color='b')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual MPG')
plt.ylabel('Predicted MPG')
plt.title('Actual vs. Predicted MPG')
plt.show()

# %% [markdown]
# **전체 차량 분석 결과**

# %%
data = pd.read_csv('car5_train.csv')
data = data.loc[data['typeofcar'] == 1]
data = data.loc[data['typeofoil'] != 2]
df_x_data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2']]
df_y_data = data['grade']

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.1, random_state=42)

# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 0.11095888350780286
# R^2 Score: 0.9181961292506249
# Intercept: -1.3753998933476645
# Coefficient: [-7.62787070e-01 -4.06568261e-05  2.08981273e-04  3.08013782e-02]

# %% [markdown]
# **전체 차량 분석 결과 + 비율 같게 조정**

# %%
data = pd.read_csv('car5_train.csv')
data = data.loc[data['typeofcar'] == 1]
data = data.loc[data['typeofoil'] != 2]
df_x_data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2']]
df_y_data = data['grade']

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.1, random_state=42, stratify= data['typeofoil'])

# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 0.06443748134513194
# R^2 Score: 0.9439083370218581
# Intercept: -1.3632045492899572
# Coefficient: [-7.66942447e-01 -3.07584113e-05  1.96107578e-04  3.07738428e-02]

# %% [markdown]
# **경우 차량 분석 결과 + TEST SIZE 조절**

# %%
data = pd.read_csv('car5_train.csv')
data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2', 'typeofcar', 'grade']]
data = data.loc[data['typeofcar'] == 1]
data = data.loc[data['typeofoil'] == 1]
df_x_data = data.loc[:,['typeofoil','displacement', 'empty_vehicle_weight', 'CO2']]
df_y_data = data['grade']

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.1, random_state=42)

# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 0.06958834894692396
# R^2 Score: 0.930411651053076
# Intercept: -2.530918754647649
# Coefficient: [0.00000000e+00 2.29412845e-04 3.77599843e-07 3.20975459e-02]
